# %% [markdown]
# # Spark over YT in Jupyter

# %% [markdown]
# This notebook demonstrates how to work with [Spark over YTsaurus](https://ytsaurus.tech/docs/en/user-guide/data-processing/spyt/overview) in a `Jupyter` notebook. We explore the following steps:
# 1. Setting up a new standalone `Spyt` cluster.
# 2. Connecting to the `Spyt` cluster from `PySpark` and running queries.

# %% [markdown]
# ## Prepare Spyt cluster

# %% [markdown]
# If you already have a running `Spyt` cluster, specify its directory in the variable `user_spark_discovery_path` below.

# %%
user_spark_discovery_path = None

# %%
import uuid
import subprocess
import sys
import random
import os 

import yt.wrapper as yt

# %%
working_dir = f"//tmp/examples/spark-over-yt-in-jupyter_{uuid.uuid4()}"
yt.create("map_node", working_dir, recursive=True)
print(working_dir)
# Out:
# //tmp/examples/spark-over-yt-in-jupyter_392d7561-f2c5-4b2c-bdee-aacff4207ba9

# %% [markdown]
# If `user_spark_discovery_path` is not specified, we will create a new small `Spyt` cluster and shut it down at the end of the notebook.

# %%
spark_discovery_path = user_spark_discovery_path

if spark_discovery_path is None:
    spark_discovery_path = working_dir
    port = random.randint(27100, 27200)

    proxy = os.environ["YT_PROXY"]
    spark_launch_command = [
        "spark-launch-yt",
        "--proxy", proxy,
        "--operation-alias", f"spark-over-yt-in-jupyt-example-{uuid.uuid4()}",
        "--worker-cores", "2",
        "--worker-num", "1",
        "--worker-memory", "64G",
        "--discovery-path", spark_discovery_path,
        "--params", f'{{spark_conf={{spark.shuffle.service.port={port}}}}}',
        "--abort-existing"
    ]
    print(" ".join(spark_launch_command))

    process = subprocess.Popen(spark_launch_command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, env=os.environ)
    stdout, stderr = process.communicate()
    print("Exit code: ", process.poll())
    print("Stdout: ", stdout.decode())
    print("Stderr: ", stderr.decode())
# Out:
# spark-launch-yt --proxy http://playground.yt.nebius.yt --operation-alias spark-over-yt-in-jupyt-example-040c8ea6-0715-4502-9636-f764fce5f44c --worker-cores 2 --worker-num 1 --worker-memory 64G --discovery-path //tmp/examples/spark-over-yt-in-jupyter_392d7561-f2c5-4b2c-bdee-aacff4207ba9 --params {spark_conf={spark.shuffle.service.port=27166}} --abort-existing
# Exit code:  0
# Stdout:
# Stderr:  2025-01-21 19:43:58,337 - INFO - spyt.standalone - 2.4.4 cluster version will be launched
# 2025-01-21 19:43:58,337 - INFO - spyt.standalone - Tmpfs is enabled, spills will be created at RAM
# 2025-01-21 19:43:58,337 - INFO - spyt.standalone - No disk account is specified
# 2025-01-21 19:43:58,337 - INFO - spyt.standalone - Launcher files will be placed to tmpfs
# 2025-01-21 19:43:58,360 - WARNING - spyt.enabler - enable_solomon_agent is enabled in start arguments, but disabled for current cluster version. It will be disabled
# 2025-01-21 19:43:58,719	INFO	Operation started: https://playground.tracto.ai/playground/operations/fc901496-187c6be9-134403e8-3ad0c5c2/details
# 2025-01-21 19:43:58,733	INFO	( 0 min) operation fc901496-187c6be9-134403e8-3ad0c5c2 initializing
# 2025-01-21 19:44:03,780	INFO	( 0 min) Unrecognized spec: {'enable_partitioned_data_balancing': false}
# 2025-01-21 19:44:03,804	INFO	( 0 min) operation fc901496-187c6be9-134403e8-3ad0c5c2: running=0     completed=0     pending=3     failed=0     aborted=0     lost=0     total=3     blocked=0
# 2025-01-21 19:44:08,905	INFO	( 0 min) operation fc901496-187c6be9-134403e8-3ad0c5c2: running=3     completed=0     pending=0     failed=0     aborted=0     lost=0     total=3     blocked=0
# 2025-01-21 19:44:49,387 - INFO - spyt.standalone - Master operation fc901496-187c6be9-134403e8-3ad0c5c2
# 2025-01-21 19:44:49,408 - INFO - spyt.standalone - Spark Master's Web UI: http://man0-0630.hw.nebius.yt:27093

# %% [markdown]
# ## Run query

# %% [markdown]
# Let's run a query by `pyspark` library using `spyt` helper.
#
# `spyt.spark_session` is a helper function to connect to the Spyt cluster. The session object behaves the same way as the original one from [pyspark](https://spark.apache.org/docs/latest/api/python/index.html).

# %% [markdown]
# Let's find all the running squirrels in a dataset about squirrels from New York's Central Park.

# %%
from spyt import spark_session
with spark_session(discovery_path=spark_discovery_path) as spark:
    df = spark.read.yt("//home/samples/squirrels")
    filtered = df.filter(df["running"] == True)
    filtered.show()
# Out:
# log4j:WARN No appenders could be found for logger (tech.ytsaurus.spyt.patch.SparkPatchAgent).
# log4j:WARN Please initialize the log4j system properly.
# log4j:WARN See http://logging.apache.org/log4j/1.2/faq.html#noconfig for more info.
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by javassist.util.proxy.SecurityActions (file:/usr/local/lib/python3.12/site-packages/pyspark/jars/javassist-3.25.0-GA.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of javassist.util.proxy.SecurityActions
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 25/01/21 19:44:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27001. Attempting port 27002.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27002. Attempting port 27003.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27003. Attempting port 27004.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27004. Attempting port 27005.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27005. Attempting port 27006.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27006. Attempting port 27007.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27007. Attempting port 27008.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27008. Attempting port 27009.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27009. Attempting port 27010.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27010. Attempting port 27011.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27011. Attempting port 27012.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27012. Attempting port 27013.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27013. Attempting port 27014.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27014. Attempting port 27015.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27015. Attempting port 27016.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27016. Attempting port 27017.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27017. Attempting port 27018.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27018. Attempting port 27019.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27019. Attempting port 27020.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27020. Attempting port 27021.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27021. Attempting port 27022.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27022. Attempting port 27023.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27023. Attempting port 27024.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27024. Attempting port 27025.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27025. Attempting port 27026.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27026. Attempting port 27027.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27027. Attempting port 27028.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27028. Attempting port 27029.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27029. Attempting port 27030.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27030. Attempting port 27031.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27031. Attempting port 27032.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27032. Attempting port 27033.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27033. Attempting port 27034.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27034. Attempting port 27035.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27035. Attempting port 27036.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27036. Attempting port 27037.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27037. Attempting port 27038.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27038. Attempting port 27039.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27039. Attempting port 27040.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27040. Attempting port 27041.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27041. Attempting port 27042.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27042. Attempting port 27043.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27043. Attempting port 27044.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27044. Attempting port 27045.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27045. Attempting port 27046.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27046. Attempting port 27047.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27047. Attempting port 27048.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27048. Attempting port 27049.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27049. Attempting port 27050.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27050. Attempting port 27051.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27051. Attempting port 27052.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27052. Attempting port 27053.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27053. Attempting port 27054.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27054. Attempting port 27055.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27055. Attempting port 27056.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27056. Attempting port 27057.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27057. Attempting port 27058.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27058. Attempting port 27059.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27059. Attempting port 27060.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27060. Attempting port 27061.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27061. Attempting port 27062.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27062. Attempting port 27063.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27063. Attempting port 27064.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27064. Attempting port 27065.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27065. Attempting port 27066.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27066. Attempting port 27067.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27067. Attempting port 27068.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27068. Attempting port 27069.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27069. Attempting port 27070.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27070. Attempting port 27071.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 27071. Attempting port 27072.
# 25/01/21 19:44:52 WARN Utils: Service 'sparkDriver' could not bind on port 

# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27034. Attempting port 27035.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27035. Attempting port 27036.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27036. Attempting port 27037.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27037. Attempting port 27038.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27038. Attempting port 27039.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27039. Attempting port 27040.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27040. Attempting port 27041.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27041. Attempting port 27042.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27042. Attempting port 27043.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27043. Attempting port 27044.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27044. Attempting port 27045.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27045. Attempting port 27046.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27046. Attempting port 27047.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27047. Attempting port 27048.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27048. Attempting port 27049.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27049. Attempting port 27050.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27050. Attempting port 27051.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27051. Attempting port 27052.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27052. Attempting port 27053.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27053. Attempting port 27054.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27054. Attempting port 27055.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27055. Attempting port 27056.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27056. Attempting port 27057.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27057. Attempting port 27058.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27058. Attempting port 27059.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27059. Attempting port 27060.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27060. Attempting port 27061.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27061. Attempting port 27062.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27062. Attempting port 27063.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27063. Attempting port 27064.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27064. Attempting port 27065.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27065. Attempting port 27066.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27066. Attempting port 27067.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27067. Attempting port 27068.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27068. Attempting port 27069.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27069. Attempting port 27070.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27070. Attempting port 27071.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27071. Attempting port 27072.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27072. Attempting port 27073.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27073. Attempting port 27074.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27074. Attempting port 27075.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27075. Attempting port 27076.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27076. Attempting port 27077.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27077. Attempting port 27078.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27078. Attempting port 27079.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27079. Attempting port 27080.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27080. Attempting port 27081.
# 25/01/21 19:44:53 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27081. Attempting port 27082.
# 2025-01-21 19:44:54,625 - INFO - spyt.client - SPYT Cluster version: 2.4.4
# 2025-01-21 19:44:54,626 - INFO - spyt.client - SPYT library version: 2.4.4
# 25/01/21 19:44:58 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +-----------------+----------------+--------------+-------+-----+----------+-----------------------+--------+-----------------+-------------------+-----------+------------+--------------------------------+-----------------+-------+-------+--------+------+--------+--------------------+-----+-----+-----+----------+-------------+----------+-----------+---------+------------------+
# |              lat|             lon|   squirrel_id|hectare|shift|      date|hectare_squirrel_number|     age|primary_fur_color|highlight_fur_color|color_notes|    location|above_ground_sighter_measurement|specific_location|running|chasing|climbing|eating|foraging|    other_activities| kuks|quaas|moans|tail_flags|tail_twitches|approaches|indifferent|runs_from|other_interactions|
# +-----------------+----------------+--------------+-------+-----+----------+-----------------------+--------+-----------------+-------------------+-----------+------------+--------------------------------+-----------------+-------+-------+--------+------+--------+--------------------+-----+-----+-----+----------+-------------+----------+-----------+---------+------------------+
# |-73.9640032826529|40.7820309825448|22F-PM-1014-06|    22F|   PM|2018-10-14|                      6|   Adult|             Gray|                   |           |Ground Plane|                           FALSE|                 |   true|  false|   false| false|   false|                    |false|false|false|     false|         true|     false|       true|    false|                  |
# |-73.9768603630674|40.7702795904962| 5C-PM-1010-09|    05C|   PM|2018-10-10|                      9|   Adult|         Cinnamon|               Gray|           |Ground Plane|                           FALSE|                 |   true|  false|   false| false|   false|                    |false|false|false|     false|        false|     false|      false|    false|                  |
# |-73.9703781726172|40.7787526130321|16C-PM-1018-03|    16C|   PM|2018-10-18|                      3|   Adult|             Gray|    Cinnamon, White|           |Above Ground|                               6|                 |   true|  false|   false|  true|    true|                    |false|false|false|     false|        false|     false|       true|    false|                  |
# |-73.9671130680114|40.7784859700171|17F-AM-1007-07|    17F|   AM|2018-10-07|                      7|   Adult|             Gray|              White|           |Above Ground|                              24|                 |   true|  false|   false| false|   false|                    |false|false|false|      true|        false|     false|       true|    false|                  |
# | -73.958736593111|40.7908524370626|32F-PM-1008-07|    32F|   PM|2018-10-08|                      7|   Adult|             Gray|                   |           |Ground Plane|                           FALSE|                 |   true|   true|   false| false|    true|                    |false|false|false|     false|        false|     false|       true|    false|                  |
# |-73.9692943291611|40.7769536102488|15E-AM-1013-01|    15E|   AM|2018-10-13|                      1|   Adult|             Gray|              White|           |Ground Plane|                           FALSE|                 |   true|  false|   false| false|    true|                    |false|false|false|     false|        false|     false|      false|    false|                  |
# |-73.9540054100539|40.7952445999836|39G-PM-1013-06|    39G|   PM|2018-10-13|                      6|   Adult|             Gray|           Cinnamon|           |Ground Plane|                           FALSE|                 |   true|  false|   false| false|   false|                    |false|false|false|     false|        false|     false|      false|    false|                  |
# |-73.9662438996681|40.7890381809441|28A-PM-1007-05|    28A|   PM|2018-10-07|                      5|   Adult|         Cinnamon|                   |           |Ground Plane|                           FALSE|                 |   true|  false|   false| false|    true|                    |false|false|false|     false|         true|     false|      false|     true|                  |
# |-73.9639159298446|40.7891774637988|29C-AM-1007-06|    29C|   AM|2018-10-07|                      6|   Adult|             Gray|           Cinnamon|           |Ground Plane|                           FALSE|                 |   true|  false|   false| false|   false|                    |false|false|false|     false|        false|     false|      false|     true|                  |
# |-73.9574648097543|40.7892508428622|31H-PM-1008-02|    31H|   PM|2018-10-08|                      2|Juvenile|             Gray|           Cinnamon|           |Above Ground|                               8|                 |   true|  false|    true| false|   false|                    |false|false|false|     false|         true|     false|       true|    false|                  |
# |-73.9579645940414|40.7918613498407|34F-AM-1007-01|    34F|   AM|2018-10-07|                      1|   Adult|             Gray|              White|           |Above Ground|                              25|                 |   true|  false|    true| false|   false|                    |false|false|false|     false|        false|     false|      false|     true|                  |
# |-73.9801666435401|40.7686905339212| 2B-PM-1013-01|    02B|   PM|2018-10-13|                      1|   Adult|             Gray|              White|           |Ground Plane|                           FALSE|                 |   true|  false|   false| false|   false|  running (with nut)|false|false|false|     false|        false|     false|      false|    false|                  |
# |-73.9584970643213|40.7982886348696|40B-AM-1019-03|    40B|   AM|2018-10-19|                      3|Juvenile|             Gray|              White|           |Ground Plane|                           FALSE|                 |   true|   true|   false| false|   false|                    |false|false|false|     false|         true|      true|      false|    false|                  |
# |-73.9568802149818|40.7972399133816|39C-PM-1006-01|    39C|   PM|2018-10-06|                      1|   Adult|             Gray|                   |           |Ground Plane|                           FALSE|                 |   true|  false|   false| false|    true|                    |false|false|false|     false|        false|     false|       true|    false|                  |
# |-73.9745630038492|40.7692602628745| 5E-AM-1008-06|    05E|   AM|2018-10-08|                      6|   Adult|         Cinnamon|              White|           |Ground Plane|                           FALSE|                 |   true|  false|   false| false|   false|                    |false|false|false|     false|        false|      true|      false|    false|                  |
# |-73.9610705592868|40.7914829661051|32D-AM-1013-06|    32D|   AM|2018-10-13|                      6|   Adult|         Cinnamon|                   |           |Ground Plane|                           FALSE|                 |   true|  false|   false|  true|    true|eating (a mushroo...|false|false|false|     false|         true|      true|      false|    false|                  |
# |-73.9578237168359|40.7980959471034|40B-PM-1014-06|    40B|   PM|2018-10-14|                      6|   Adult|             Gray|           Cinnamon|           |Ground Plane|                           FALSE|                 |   true|  false|   false| false|   false|                    |false|false|false|     false|        false|     false|       true|    false|                  |
# |-73.9688271202401|40.7809719445309|19C-PM-1018-01|    19C|   PM|2018-10-18|                      1|   Adult|             Gray|              White|           |Ground Plane|                           FALSE|                 |   true|   true|   false|  true|   false|                    |false|false|false|     false|         true|     false|       true|    false|                  |
# |-73.9617088749928|40.7944585082367|35A-PM-1013-06|    35A|   PM|2018-10-13|                      6|   Adult|         Cinnamon|                   |           |Ground Plane|                           FALSE|                 |   true|  false|   false| false|   false|                    |false|false|false|     false|        false|     false|      false|     true|                  |
# |-73.9701824825872|40.7766530579293|14E-AM-1008-09|    14E|   AM|2018-10-08|                      9|   Adult|             Gray|                   |           |Ground Plane|                           FALSE|                 |   true|   true|   false| false|   false|                    | true|false|false|     false|        false|     false|      false|     true|                  |
# +-----------------+----------------+--------------+-------+-----+----------+-----------------------+--------+-----------------+-------------------+-----------+------------+--------------------------------+-----------------+-------+-------+--------+------+--------+--------------------+-----+-----+-----+----------+-------------+----------+-----------+---------+------------------+
# only showing top 20 rows
# 2025-01-21 19:45:01,272 - INFO - py4j.clientserver - Closing down clientserver connection
# 2025-01-21 19:45:01,273 - INFO - py4j.clientserver - Closing down clientserver connection
# 2025-01-21 19:45:01,273 - INFO - py4j.clientserver - Closing down clientserver connection
# 2025-01-21 19:45:01,273 - INFO - py4j.clientserver - Closing down clientserver connection

# %% [markdown]
# ### Run query with UDF

# %% [markdown]
# You can run spark queries with [UDF](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.functions.udf.html).

# %%
from pyspark.sql.functions import udf

@udf
def to_upper(s):
    if s is not None:
        return s.upper()

with spark_session(discovery_path=spark_discovery_path) as spark:
    display(spark.read.yt("//home/samples/squirrels").select(to_upper("age")).limit(20).toPandas())
# Out:
# log4j:WARN No appenders could be found for logger (tech.ytsaurus.spyt.patch.SparkPatchAgent).
# log4j:WARN Please initialize the log4j system properly.
# log4j:WARN See http://logging.apache.org/log4j/1.2/faq.html#noconfig for more info.
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by javassist.util.proxy.SecurityActions (file:/usr/local/lib/python3.12/site-packages/pyspark/jars/javassist-3.25.0-GA.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of javassist.util.proxy.SecurityActions
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 25/01/21 19:45:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27001. Attempting port 27002.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27002. Attempting port 27003.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27003. Attempting port 27004.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27004. Attempting port 27005.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27005. Attempting port 27006.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27006. Attempting port 27007.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27007. Attempting port 27008.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27008. Attempting port 27009.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27009. Attempting port 27010.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27010. Attempting port 27011.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27011. Attempting port 27012.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27012. Attempting port 27013.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27013. Attempting port 27014.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27014. Attempting port 27015.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27015. Attempting port 27016.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27016. Attempting port 27017.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27017. Attempting port 27018.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27018. Attempting port 27019.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27019. Attempting port 27020.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27020. Attempting port 27021.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27021. Attempting port 27022.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27022. Attempting port 27023.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27023. Attempting port 27024.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27024. Attempting port 27025.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27025. Attempting port 27026.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27026. Attempting port 27027.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27027. Attempting port 27028.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27028. Attempting port 27029.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27029. Attempting port 27030.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27030. Attempting port 27031.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27031. Attempting port 27032.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27032. Attempting port 27033.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27033. Attempting port 27034.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27034. Attempting port 27035.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27035. Attempting port 27036.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27036. Attempting port 27037.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27037. Attempting port 27038.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27038. Attempting port 27039.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27039. Attempting port 27040.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 27040. Attempting port 27041.
# 25/01/21 19:45:04 WARN Utils: Service 'sparkDriver' could not bind on port 

# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27001. Attempting port 27002.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27002. Attempting port 27003.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27003. Attempting port 27004.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27004. Attempting port 27005.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27005. Attempting port 27006.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27006. Attempting port 27007.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27007. Attempting port 27008.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27008. Attempting port 27009.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27009. Attempting port 27010.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27010. Attempting port 27011.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27011. Attempting port 27012.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27012. Attempting port 27013.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27013. Attempting port 27014.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27014. Attempting port 27015.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27015. Attempting port 27016.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27016. Attempting port 27017.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27017. Attempting port 27018.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27018. Attempting port 27019.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27019. Attempting port 27020.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27020. Attempting port 27021.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27021. Attempting port 27022.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27022. Attempting port 27023.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27023. Attempting port 27024.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27024. Attempting port 27025.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27025. Attempting port 27026.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27026. Attempting port 27027.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27027. Attempting port 27028.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27028. Attempting port 27029.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27029. Attempting port 27030.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27030. Attempting port 27031.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27031. Attempting port 27032.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27032. Attempting port 27033.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27033. Attempting port 27034.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27034. Attempting port 27035.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27035. Attempting port 27036.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27036. Attempting port 27037.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27037. Attempting port 27038.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27038. Attempting port 27039.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27039. Attempting port 27040.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27040. Attempting port 27041.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27041. Attempting port 27042.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27042. Attempting port 27043.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27043. Attempting port 27044.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27044. Attempting port 27045.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27045. Attempting port 27046.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27046. Attempting port 27047.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27047. Attempting port 27048.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27048. Attempting port 27049.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27049. Attempting port 27050.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27050. Attempting port 27051.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27051. Attempting port 27052.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27052. Attempting port 27053.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27053. Attempting port 27054.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27054. Attempting port 27055.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27055. Attempting port 27056.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27056. Attempting port 27057.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27057. Attempting port 27058.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27058. Attempting port 27059.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27059. Attempting port 27060.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27060. Attempting port 27061.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27061. Attempting port 27062.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27062. Attempting port 27063.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27063. Attempting port 27064.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27064. Attempting port 27065.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27065. Attempting port 27066.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27066. Attempting port 27067.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27067. Attempting port 27068.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27068. Attempting port 27069.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27069. Attempting port 27070.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27070. Attempting port 27071.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27071. Attempting port 27072.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27072. Attempting port 27073.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27073. Attempting port 27074.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27074. Attempting port 27075.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27075. Attempting port 27076.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27076. Attempting port 27077.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27077. Attempting port 27078.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27078. Attempting port 27079.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27079. Attempting port 27080.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27080. Attempting port 27081.
# 25/01/21 19:45:05 WARN Utils: Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 27081. Attempting port 27082.
# 2025-01-21 19:45:06,678 - INFO - spyt.client - SPYT Cluster version: 2.4.4
# 2025-01-21 19:45:06,680 - INFO - spyt.client - SPYT library version: 2.4.4
#    to_upper(age)
# 0
# 1
# 2
# 3          ADULT
# 4          ADULT
# 5          ADULT
# 6          ADULT
# 7          ADULT
# 8          ADULT
# 9          ADULT
# 10         ADULT
# 11         ADULT
# 12         ADULT
# 13         ADULT
# 14         ADULT
# 15         ADULT
# 16         ADULT
# 17      JUVENILE
# 18         ADULT
# 19         ADULT
# 2025-01-21 19:45:15,731 - INFO - py4j.clientserver - Closing down clientserver connection
# 2025-01-21 19:45:15,732 - INFO - py4j.clientserver - Closing down clientserver connection
# 2025-01-21 19:45:15,733 - INFO - py4j.clientserver - Closing down clientserver connection
# 2025-01-21 19:45:15,733 - INFO - py4j.clientserver - Closing down clientserver connection

# %% [markdown]
# ## Stop temporary SPYT cluster

# %%
if not user_spark_discovery_path:
    operations = yt.list(f"{spark_discovery_path}/discovery/operation")
    assert len(operations) == 1
    yt.abort_operation(operation=operations[0])
